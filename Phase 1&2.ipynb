# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\91897\anaconda3\lib\site-packages (0.2.1)

# %% [markdown]
# # Phase 2

# %% [markdown]
# I collected the data from diffrenet sources for population , Litercay rate and others as well. I found the census data for 2001 then 2011 so I found the Growth rate for population for 10 years and applied that rate (Annualy) for finding the population form 2002 to 2012. Here I got columns in my data set are-
#
# * State/UT: Each state present in india.
#
# * Year : 2001 to 2012
#
# * population(total)- total population of state or UT in each year from 2001 to 2012
#
# * Rural : Population of Rural area of that state
#
# * 'Urban :Population of urban area of that state,
#
# * 'Tot_M' : Total population of Males present in that State/UT
#
# * 'Tot_F' : Total population of Females present in that State/UT,
#
# * 'P_LIT' - Total Literate population of each state,
#
# * 'M_LIT' : Male literacy population of each state
#
# * F_LIT : Female literate population in each state
#
# * Lit_rate : Literacy Rate
#
# * Area- Area in KM square of each state
#
# * Murder- number of murder in each stae
#
# * 'ATTEMPT TO MURDER',
#
# * 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',
#
# * 'RAPE',
#
# * 'CUSTODIAL RAPE',
#
# * 'OTHER RAPE',
#
# * 'KIDNAPPING & ABDUCTION',
#
# * 'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#
# * 'KIDNAPPING AND ABDUCTION OF OTHERS',
#
# * 'DACOITY',
#
# * 'PREPARATION AND ASSEMBLY FOR DACOITY',
#
# * 'ROBBERY',
#
# * 'BURGLARY',
#
# * 'THEFT',
#
# * 'AUTO THEFT',
#
# * 'OTHER THEFT',
#
# * 'RIOTS',
#
# * 'CRIMINAL BREACH OF TRUST',
#
# * 'CHEATING',
#
# * 'COUNTERFIETING',
#
# * 'ARSON',
#
# * 'HURT/GREVIOUS HURT',
#
# * 'DOWRY DEATHS',
#
# * ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#
# * 'INSULT TO MODESTY OF WOMEN',
#
# * 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#
# * 'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#
# * 'CAUSING DEATH BY NEGLIGENCE',
#
# * 'OTHER IPC CRIMES',
#
# * 'TOTAL IPC CRIMES',
#
# * 'Total Crimes',
#
# * 'tot_crimes_sc': Total crimes against SC comitted in each year,
#
# * 'total crime against women : Total crimes against Women comitted in each year,
#
# * 'Total crimes against STs': Total crimes against STs comitted in each year,
#
# * 'Total crime against children- Total crimes against Children comitted in each year
#
# * Crime Rate- A crime rate is defined as the total number of crimes performed per a certain number of people in a specified area. This is typically expressed per 100,000 people.

# %%
! pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\91897\anaconda3\lib\site-packages (0.2.1)

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

import plotly.express as px
import plotly 
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import init_notebook_mode

# %%
df = pd.read_csv("Final_data2.csv")

# %%
df
# Out:
#               State/UT  Year  population(total)     Rural     Urban     Tot_M  \
# 0         A& N ISLANDS  2001             356152    239954    116198    192972
# 1       ANDHRA PRADESH  2001           76210007  55401067  20808940  38527413
# 2    ARUNACHAL PRADESH  2001            1097968    870087    227881    579941
# 3                ASSAM  2001           26655528  23216288   3439240  13777037
# 4                BIHAR  2001           82998509  74316709   8681800  43243795
# ..                 ...   ...                ...       ...       ...       ...
# 214              BIHAR  2007           95131440  85180514   9950926  49856699
# 215         CHANDIGARH  2007             990623    101321    889302    551037
# 216       CHHATTISGARH  2007           23600592  18858967   4741625  11865223
# 217       D & N HAVELI  2007             287128    221417     65711    162111
# 218        DAMAN & DIU  2007             204836    130584     74252    123971
#
#         Tot_F       P_LIT       M_LIT     F_LIT  ...  \
# 0      163180    253135.0    146831.0    106304  ...
# 1    37682594  39934323.0  23444788.0  16489535  ...
# 2      518027    484785.0    303281.0    181504  ...
# 3    12878491  14015354.0   8188697.0   5826657  ...
# 4    39754714  31109577.0  20644376.0  10465201  ...
# ..        ...         ...         ...       ...  ...
# 214  45566158  42612756.0  26730354.0  15882402  ...
# 215    443363    735944.0    428435.0    307509  ...
# 216  11735367  13533887.0   7920841.0   5613046  ...
# 217    126489    165133.0    109493.0     55640  ...
# 218     80749    150328.0     99566.0     50762  ...
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                              0                            0
# 1                                              7                         7400
# 2                                              0                            0
# 3                                              0                         2010
# 4                                             83                         2406
# ..                                           ...                          ...
# 214                                           56                         3789
# 215                                            0                           15
# 216                                            0                         2476
# 217                                            0                           12
# 218                                            0                           12
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES  Total Crimes  tot_crimes_sc  \
# 0                 323               658          1386              0
# 1               34344            130089        278982           2933
# 2                 618              2342          5243              0
# 3                9315             36877         81418              6
# 4               36667             88432        189612           1303
# ..                ...               ...           ...            ...
# 214             44931            109420        234720           2786
# 215               999              3643          9100              0
# 216             19505             45845         98297            511
# 217               161               425           953              0
# 218               161               425           953              0
#
#      total crime against women  Total crimes against STs  \
# 0                           34                       1.0
# 1                        13669                     512.0
# 2                          180                      72.0
# 3                         4048                       0.0
# 4                         4489                      83.0
# ..                         ...                       ...
# 214                       9644                     675.0
# 215                       7511                       NaN
# 216                        146                       NaN
# 217                       3976                       NaN
# 218                         19                       NaN
#
#      Total crime against children  Crime Rate
# 0                             0.0  184.752578
# 1                           270.0  170.698055
# 2                             0.0  213.303120
# 3                            18.0  138.346537
# 4                            83.0  106.546492
# ..                            ...         ...
# 214                         675.0  115.019808
# 215                          53.0  367.748377
# 216                        1024.0  194.253602
# 217                          11.0  148.017609
# 218                           3.0  207.483060
#
# [219 rows x 48 columns]

# %%
df.head()
# Out:
#             State/UT  Year  population(total)     Rural     Urban     Tot_M  \
# 0       A& N ISLANDS  2001             356152    239954    116198    192972
# 1     ANDHRA PRADESH  2001           76210007  55401067  20808940  38527413
# 2  ARUNACHAL PRADESH  2001            1097968    870087    227881    579941
# 3              ASSAM  2001           26655528  23216288   3439240  13777037
# 4              BIHAR  2001           82998509  74316709   8681800  43243795
#
#       Tot_F       P_LIT       M_LIT     F_LIT  ...  \
# 0    163180    253135.0    146831.0    106304  ...
# 1  37682594  39934323.0  23444788.0  16489535  ...
# 2    518027    484785.0    303281.0    181504  ...
# 3  12878491  14015354.0   8188697.0   5826657  ...
# 4  39754714  31109577.0  20644376.0  10465201  ...
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                            0
# 1                                            7                         7400
# 2                                            0                            0
# 3                                            0                         2010
# 4                                           83                         2406
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES  Total Crimes  tot_crimes_sc  \
# 0               323               658          1386              0
# 1             34344            130089        278982           2933
# 2               618              2342          5243              0
# 3              9315             36877         81418              6
# 4             36667             88432        189612           1303
#
#    total crime against women  Total crimes against STs  \
# 0                         34                       1.0
# 1                      13669                     512.0
# 2                        180                      72.0
# 3                       4048                       0.0
# 4                       4489                      83.0
#
#    Total crime against children  Crime Rate
# 0                           0.0  184.752578
# 1                         270.0  170.698055
# 2                           0.0  213.303120
# 3                          18.0  138.346537
# 4                          83.0  106.546492
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#          State/UT  Year  population(total)     Rural    Urban     Tot_M  \
# 214         BIHAR  2007           95131440  85180514  9950926  49856699
# 215    CHANDIGARH  2007             990623    101321   889302    551037
# 216  CHHATTISGARH  2007           23600592  18858967  4741625  11865223
# 217  D & N HAVELI  2007             287128    221417    65711    162111
# 218   DAMAN & DIU  2007             204836    130584    74252    123971
#
#         Tot_F       P_LIT       M_LIT     F_LIT  ...  \
# 214  45566158  42612756.0  26730354.0  15882402  ...
# 215    443363    735944.0    428435.0    307509  ...
# 216  11735367  13533887.0   7920841.0   5613046  ...
# 217    126489    165133.0    109493.0     55640  ...
# 218     80749    150328.0     99566.0     50762  ...
#
#      IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 214                                           56                         3789
# 215                                            0                           15
# 216                                            0                         2476
# 217                                            0                           12
# 218                                            0                           12
#
#      OTHER IPC CRIMES  TOTAL IPC CRIMES  Total Crimes  tot_crimes_sc  \
# 214             44931            109420        234720           2786
# 215               999              3643          9100              0
# 216             19505             45845         98297            511
# 217               161               425           953              0
# 218               161               425           953              0
#
#      total crime against women  Total crimes against STs  \
# 214                       9644                     675.0
# 215                       7511                       NaN
# 216                        146                       NaN
# 217                       3976                       NaN
# 218                         19                       NaN
#
#      Total crime against children  Crime Rate
# 214                         675.0  115.019808
# 215                          53.0  367.748377
# 216                        1024.0  194.253602
# 217                          11.0  148.017609
# 218                           3.0  207.483060
#
# [5 rows x 48 columns]

# %%
print(f"The rows and clumns in the dataset:{df.shape}")
print(f"\n The column headers in the dataset:{df.columns}")
# Out:
# The rows and clumns in the dataset:(219, 48)
#
#  The column headers in the dataset:Index(['State/UT', 'Year', 'population(total)', 'Rural', 'Urban', 'Tot_M',
#        'Tot_F', 'P_LIT', 'M_LIT', 'F_LIT', 'Lit_rate', 'Area (km2)', 'MURDER',
#        'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',
#        'RAPE', 'CUSTODIAL RAPE', 'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'Total Crimes', 'tot_crimes_sc', 'total crime against women',
#        'Total crimes against STs', 'Total crime against children',
#        'Crime Rate'],
#       dtype='object')

# %% [markdown]
# In this final dataset we have 219 rows and 49 columns and the names/headers of the columns are follow as above.

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 48 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   State/UT                                             219 non-null    object
#  1   Year                                                 219 non-null    int64
#  2   population(total)                                    219 non-null    int64
#  3   Rural                                                219 non-null    int64
#  4   Urban                                                219 non-null    int64
#  5   Tot_M                                                219 non-null    int64
#  6   Tot_F                                                219 non-null    int64
#  7   P_LIT                                                219 non-null    float64
#  8   M_LIT                                                219 non-null    float64
#  9   F_LIT                                                219 non-null    int64
#  10  Lit_rate                                             219 non-null    float64
#  11  Area (km2)                                           219 non-null    int64
#  12  MURDER                                               219 non-null    int64
#  13  ATTEMPT TO MURDER                                    219 non-null    int64
#  14  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            219 non-null    int64
#  15  RAPE                                                 219 non-null    int64
#  16  CUSTODIAL RAPE                                       219 non-null    int64
#  17  OTHER RAPE                                           219 non-null    int64
#  18  KIDNAPPING & ABDUCTION                               219 non-null    int64
#  19  KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS          219 non-null    int64
#  20  KIDNAPPING AND ABDUCTION OF OTHERS                   219 non-null    int64
#  21  DACOITY                                              219 non-null    int64
#  22  PREPARATION AND ASSEMBLY FOR DACOITY                 219 non-null    int64
#  23  ROBBERY                                              219 non-null    int64
#  24  BURGLARY                                             219 non-null    int64
#  25  THEFT                                                219 non-null    int64
#  26  AUTO THEFT                                           219 non-null    int64
#  27  OTHER THEFT                                          219 non-null    int64
#  28  RIOTS                                                219 non-null    int64
#  29  CRIMINAL BREACH OF TRUST                             219 non-null    int64
#  30  CHEATING                                             219 non-null    int64
#  31  COUNTERFIETING                                       219 non-null    int64
#  32  ARSON                                                219 non-null    int64
#  33  HURT/GREVIOUS HURT                                   219 non-null    int64
#  34  DOWRY DEATHS                                         219 non-null    int64
#  35  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  219 non-null    int64
#  36  INSULT TO MODESTY OF WOMEN                           219 non-null    int64
#  37  CRUELTY BY HUSBAND OR HIS RELATIVES                  219 non-null    int64
#  38  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES          219 non-null    int64
#  39  CAUSING DEATH BY NEGLIGENCE                          219 non-null    int64
#  40  OTHER IPC CRIMES                                     219 non-null    int64
#  41  TOTAL IPC CRIMES                                     219 non-null    int64
#  42  Total Crimes                                         219 non-null    int64
#  43  tot_crimes_sc                                        219 non-null    int64
#  44  total crime against women                            219 non-null    int64
#  45  Total crimes against STs                             201 non-null    float64
#  46  Total crime against children                         218 non-null    float64
#  47  Crime Rate                                           219 non-null    float64
# dtypes: float64(6), int64(41), object(1)
# memory usage: 82.2+ KB

# %% [markdown]
# Here we can see that data type of each column and memory occupied and information about the Null as well

# %%
(df['State/UT'].unique())
# Out:
# array(['A& N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM',
#        'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI', 'GOA', 'GUJARAT', 'HARYANA',
#        'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA',
#        'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA',
#        'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA',
#        'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU',
#        'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# State/UT                                                0
# Year                                                    0
# population(total)                                       0
# Rural                                                   0
# Urban                                                   0
# Tot_M                                                   0
# Tot_F                                                   0
# P_LIT                                                   0
# M_LIT                                                   0
# F_LIT                                                   0
# Lit_rate                                                0
# Area (km2)                                              0
# MURDER                                                  0
# ATTEMPT TO MURDER                                       0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER               0
# RAPE                                                    0
# CUSTODIAL RAPE                                          0
# OTHER RAPE                                              0
# KIDNAPPING & ABDUCTION                                  0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS             0
# KIDNAPPING AND ABDUCTION OF OTHERS                      0
# DACOITY                                                 0
# PREPARATION AND ASSEMBLY FOR DACOITY                    0
# ROBBERY                                                 0
# BURGLARY                                                0
# THEFT                                                   0
# AUTO THEFT                                              0
# OTHER THEFT                                             0
# RIOTS                                                   0
# CRIMINAL BREACH OF TRUST                                0
# CHEATING                                                0
# COUNTERFIETING                                          0
# ARSON                                                   0
# HURT/GREVIOUS HURT                                      0
# DOWRY DEATHS                                            0
# ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY     0
# INSULT TO MODESTY OF WOMEN                              0
# CRUELTY BY HUSBAND OR HIS RELATIVES                     0
# IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES             0
# CAUSING DEATH BY NEGLIGENCE                             0
# OTHER IPC CRIMES                                        0
# TOTAL IPC CRIMES                                        0
# Total Crimes                                            0
# tot_crimes_sc                                           0
# total crime against women                               0
# Total crimes against STs                               18
# Total crime against children                            1
# Crime Rate                                              0
# dtype: int64

# %% [markdown]
# Here we can see that we have got few null values in columns
#
# * total crime against STs
# * total crime against children

# %% [markdown]
# # Filling Null Values using mean methods

# %%
df['Total crimes against STs'].describe()
# Out:
# count     201.000000
# mean      167.079602
# std       357.608786
# min         0.000000
# 25%         0.000000
# 50%         9.000000
# 75%       167.000000
# max      2504.000000
# Name: Total crimes against STs, dtype: float64

# %%
df['Total crimes against STs']=df['Total crimes against STs'].fillna(df['Total crimes against STs'].mean())

# %%
df['Total crime against children'].describe()
# Out:
# count     218.000000
# mean      385.045872
# std       727.043110
# min         0.000000
# 25%        15.000000
# 50%        68.000000
# 75%       332.000000
# max      3939.000000
# Name: Total crime against children, dtype: float64

# %%
df['Total crime against children']=df['Total crime against children'].fillna(df['Total crime against children'].mean())

# %%
# Checking again if there is null value left in Dataset

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['State/UT'].value_counts()
# Out:
# A& N ISLANDS         7
# ARUNACHAL PRADESH    7
# ASSAM                7
# BIHAR                7
# CHANDIGARH           7
# CHHATTISGARH         7
# D & N HAVELI         7
# DAMAN & DIU          7
# ANDHRA PRADESH       7
# RAJASTHAN            6
# NAGALAND             6
# ODISHA               6
# PUDUCHERRY           6
# PUNJAB               6
# UTTAR PRADESH        6
# SIKKIM               6
# TAMIL NADU           6
# TRIPURA              6
# MEGHALAYA            6
# UTTARAKHAND          6
# MIZORAM              6
# KERALA               6
# MANIPUR              6
# MAHARASHTRA          6
# MADHYA PRADESH       6
# LAKSHADWEEP          6
# KARNATAKA            6
# JHARKHAND            6
# JAMMU & KASHMIR      6
# HIMACHAL PRADESH     6
# HARYANA              6
# GUJARAT              6
# GOA                  6
# DELHI                6
# WEST BENGAL          6
# Name: State/UT, dtype: int64

# %%
df.describe()
# Out:
#               Year  population(total)         Rural         Urban  \
# count   219.000000       2.190000e+02  2.190000e+02  2.190000e+02
# mean   2003.643836       2.975058e+07  2.208278e+07  8.367930e+06
# std       1.815099       3.832550e+07  2.933469e+07  1.085730e+07
# min    2001.000000       6.065000e+04  3.368300e+04  2.696700e+04
# 25%    2002.000000       1.136138e+06  6.907185e+05  4.952730e+05
# 50%    2004.000000       1.385051e+07  7.966343e+06  3.550177e+06
# 75%    2005.000000       5.355006e+07  3.490536e+07  1.370185e+07
# max    2007.000000       1.825982e+08  1.446503e+08  4.427743e+07
#
#               Tot_M         Tot_F         P_LIT         M_LIT         F_LIT  \
# count  2.190000e+02  2.190000e+02  2.190000e+02  2.190000e+02  2.190000e+02
# mean   1.571011e+07  1.475312e+07  1.714761e+07  1.016830e+07  6.995371e+06
# std    2.002538e+07  1.849197e+07  2.081182e+07  1.252944e+07  8.389206e+06
# min    3.113100e+04  2.951900e+04  4.468300e+04  2.451100e+04  2.017200e+04
# 25%    6.109005e+05  5.578885e+05  7.433025e+05  4.165275e+05  3.490800e+05
# 50%    7.863436e+06  6.676203e+06  1.020415e+07  5.966101e+06  4.130344e+06
# 75%    2.789940e+07  2.638100e+07  3.097005e+07  1.873731e+07  1.259717e+07
# max    9.526583e+07  8.681669e+07  9.301581e+07  5.779950e+07  3.521631e+07
#
#          Lit_rate  ...  IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  \
# count  219.000000  ...                                   219.000000
# mean    71.539680  ...                                     2.726027
# std     10.088337  ...                                    11.061870
# min     47.000000  ...                                     0.000000
# 25%     64.625000  ...                                     0.000000
# 50%     70.920000  ...                                     0.000000
# 75%     79.715000  ...                                     0.000000
# max     92.670000  ...                                    83.000000
#
#        CAUSING DEATH BY NEGLIGENCE  OTHER IPC CRIMES  TOTAL IPC CRIMES  \
# count                   219.000000        219.000000        219.000000
# mean                   1933.273973      20629.273973      51062.557078
# std                    2946.408948      25596.045108      60225.862760
# min                       0.000000          5.000000         31.000000
# 25%                      24.500000        643.500000       2251.000000
# 50%                     416.000000       9316.000000      27136.000000
# 75%                    2687.500000      37605.000000     102042.000000
# max                   12629.000000      97751.000000     196867.000000
#
#         Total Crimes  tot_crimes_sc  total crime against women  \
# count     219.000000     219.000000                 219.000000
# mean   110657.968037   10926.123288                4375.863014
# std    130079.213016   75891.721670                5491.583328
# min        72.000000       0.000000                   0.000000
# 25%      5145.000000       0.000000                 112.000000
# 50%     58072.000000      16.000000                2216.000000
# 75%    213941.000000     574.500000                6198.500000
# max    432810.000000  596161.000000               23224.000000
#
#        Total crimes against STs  Total crime against children    Crime Rate
# count                219.000000                    219.000000    219.000000
# mean                 167.079602                    385.045872    274.545882
# std                  342.527095                    725.373664   1199.951862
# min                    0.000000                      0.000000     49.142622
# 25%                    0.000000                     15.000000    113.286875
# 50%                   12.000000                     68.000000    179.364938
# 75%                  167.079602                    337.000000    217.140677
# max                 2504.000000                   3939.000000  17675.007690
#
# [8 rows x 47 columns]

# %% [markdown]
# The above described method shows all the min, max, 25%, 50%, 75%, statistics of dataset.

# %% [markdown]
# # Visualization

# %%
# Plotting Pie chart for different crimes

# %%
tot_murder= df['MURDER'].sum()
tot_rape= df['RAPE'].sum()
tot_dowrydeaths = df['DOWRY DEATHS'].sum()

tot_kidnap= df['KIDNAPPING & ABDUCTION'].sum()
tot_dacoity= df['DACOITY'].sum()
tot_robbery = df['ROBBERY'].sum()
tot_burglary= df['BURGLARY'].sum()
tot_theft= df['THEFT'].sum()
tot_riots = df['DOWRY DEATHS'].sum()

crime_group = ['TOTAL Murder','TOTAL rape','Total Dowry Deaths','Total Kidnapping','TOTAL Dacoity','Total Robbery','TOtal Burglary','Total Theft','Total Riots']
values = [tot_murder,tot_rape,tot_dowrydeaths,tot_kidnap,tot_dacoity,tot_robbery,tot_burglary,tot_theft,tot_riots]

colors = ['crimson','gold','green','yellow','blue','black']

fig = go.Figure(data=[go.Pie(labels=crime_group, values=values,sort=False,
                            marker=dict(colors=colors),textfont_size=12)])

fig.show()
# Out:
# <div>                            <div id="97bb919f-fd33-41f5-be7a-eacb7aa43cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97bb919f-fd33-41f5-be7a-eacb7aa43cc7")) {                    Plotly.newPlot(                        "97bb919f-fd33-41f5-be7a-eacb7aa43cc7",                        [{"labels":["TOTAL Murder","TOTAL rape","Total Dowry Deaths","Total Kidnapping","TOTAL Dacoity","Total Robbery","TOtal Burglary","Total Theft","Total Riots"],"marker":{"colors":["crimson","gold","green","yellow","blue","black"]},"sort":false,"textfont":{"size":12},"values":[211161,109384,43298,141516,34052,114229,582409,1617959,43298],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewi ...
#
# var gd = document.getElementById('97bb919f-fd33-41f5-be7a-eacb7aa43cc7');
# v

# %% [markdown]
# #  State/UT VS Literacy Rate

# %%
plt.figure(figsize=(15, 9))
sns.barplot(x='State/UT', y='Lit_rate',data=df)
plt.xticks(rotation='90')
plt.savefig("1.jpg")
plt.show()

# %% [markdown]
# As per this barplot State Kerala has the highest Lireacy rate and Bihar has the lowest Litereacy rate.

# %%
# State/UT VS Total Crimes

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['State/UT'], y=df['Total Crimes'])
plt.xticks(rotation='90')
plt.title('State/UT Vs Total Crimes')
plt.savefig("2.jpg")
plt.show()

# %% [markdown]
# * States Arunachal Praddeh,Chandigarh,D&N Haveli,,Goa,Manipur, Meghayala,MIzoram, NAgaland,Pudducheery, Sikkim has least Total crimes as compare to Madhya Pradesh,Maharashtra, Uttar Pradesh ahs highest Total Crimes

# %%
# Years VS Total Crimes

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['Year'], y=df['Total Crimes'])
plt.title('Year Vs Total Crimes')
plt.savefig("3.jpg")
plt.show()

# %%
# State/UT VS Total crimes Against SCs

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=df['State/UT'], y=df['tot_crimes_sc'])
plt.xticks(rotation='90')
plt.title('State/UT Vs Total Crimes Against SCs')
plt.savefig("4.jpg")
plt.show()

# %% [markdown]
# * States Rajasthan has the highest crimes againast SCs , Andhra Pradesh, Bihar ,Karnataka,Madhya Pradesh,Uttar Pradesh has lesser Crimes against SCS

# %%
# State/UT VS Total crimes against Children

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['State/UT'], y=df['Total crime against children'])
plt.xticks(rotation='90')
plt.title('State/UT Vs Total Crimes Against Children')
plt.savefig("6.jpg")
plt.show()

# %% [markdown]
# * MP, UP has the Highest Crimes against Children while D & N Haveli, Daman,& Diu has the lowest Crimes against Children

# %%
# State/UT VS Total Crime against Women

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['State/UT'], y=df['total crime against women'])
plt.xticks(rotation='90')
plt.title('State/UT Vs Total Crimes Against Women')
plt.savefig("7.jpg")
plt.show()

# %% [markdown]
# * Only Mizoram and Meghalya are the only states which has lesser crime against women and Nagaland has almost 0 crimes against Women.
#
# * Other states have more crimes against Women.

# %%
# Year VS Literacy Rate

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['Year'], y=df['Lit_rate'])
plt.xticks(rotation='90')
plt.title('Year VS Litercay Rate')
plt.savefig("8.jpg")
plt.show()

# %% [markdown]
# * We can see that Literacy rate for years has been increasing each year

# %%
# Year Vs Population Literacy

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['Year'], y=df['P_LIT'])
plt.xticks(rotation='90')
plt.title('YEAR VS POPULATIN LITERACY')
plt.savefig("9.jpg")
plt.show()

# %%
# Year Vs Male Lietracy

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x=df['Year'], y=df['M_LIT'])
plt.xticks(rotation='90')
plt.title('Year VS Male Literacy')
plt.savefig("10.jpg")
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['population(total)'], y=df['P_LIT'],hue=df['State/UT'])
plt.xlabel('Population Total')
plt.ylabel('Population Literacy')
plt.title('Population VS Litercay')
plt.savefig("11.jpg")
plt.show()

# %% [markdown]
# * From above scatter its clear for every state/UT , Population is increasing so does Literacy.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # 2.1 Analysis of Literacy Rate vs Total crimes.

# %%
new_df=df[['State/UT','Year','Lit_rate', 'Total Crimes', 'tot_crimes_sc', 'total crime against women',
       'Total crimes against STs','Total crime against children']]
new_df
# Out:
#               State/UT  Year  Lit_rate  Total Crimes  tot_crimes_sc  \
# 0         A& N ISLANDS  2001     81.30          1386              0
# 1       ANDHRA PRADESH  2001     60.47        278982           2933
# 2    ARUNACHAL PRADESH  2001     54.34          5243              0
# 3                ASSAM  2001     63.25         81418              6
# 4                BIHAR  2001     47.00        189612           1303
# ..                 ...   ...       ...           ...            ...
# 214              BIHAR  2007     55.20        234720           2786
# 215         CHANDIGARH  2007     84.30          9100              0
# 216       CHHATTISGARH  2007     66.85         98297            511
# 217       D & N HAVELI  2007     68.39           953              0
# 218        DAMAN & DIU  2007     83.43           953              0
#
#      total crime against women  Total crimes against STs  \
# 0                           34                  1.000000
# 1                        13669                512.000000
# 2                          180                 72.000000
# 3                         4048                  0.000000
# 4                         4489                 83.000000
# ..                         ...                       ...
# 214                       9644                675.000000
# 215                       7511                167.079602
# 216                        146                167.079602
# 217                       3976                167.079602
# 218                         19                167.079602
#
#      Total crime against children
# 0                             0.0
# 1                           270.0
# 2                             0.0
# 3                            18.0
# 4                            83.0
# ..                            ...
# 214                         675.0
# 215                          53.0
# 216                        1024.0
# 217                          11.0
# 218                           3.0
#
# [219 rows x 8 columns]

# %%
new_df.corr()
# Out:
#                                   Year  Lit_rate  Total Crimes  tot_crimes_sc  \
# Year                          1.000000  0.120424      0.006508       0.043495
# Lit_rate                      0.120424  1.000000     -0.219593      -0.130954
# Total Crimes                  0.006508 -0.219593      1.000000       0.226883
# tot_crimes_sc                 0.043495 -0.130954      0.226883       1.000000
# total crime against women     0.122912 -0.016499      0.016118      -0.053214
# Total crimes against STs      0.007597 -0.225079      0.583125       0.237844
# Total crime against children  0.102327 -0.069129      0.719807       0.037016
#
#                               total crime against women  \
# Year                                           0.122912
# Lit_rate                                      -0.016499
# Total Crimes                                   0.016118
# tot_crimes_sc                                 -0.053214
# total crime against women                      1.000000
# Total crimes against STs                       0.027770
# Total crime against children                   0.027361
#
#                               Total crimes against STs  \
# Year                                          0.007597
# Lit_rate                                     -0.225079
# Total Crimes                                  0.583125
# tot_crimes_sc                                 0.237844
# total crime against women                     0.027770
# Total crimes against STs                      1.000000
# Total crime against children                  0.595681
#
#                               Total crime against children
# Year                                              0.102327
# Lit_rate                                         -0.069129
# Total Crimes                                      0.719807
# tot_crimes_sc                                     0.037016
# total crime against women                         0.027361
# Total crimes against STs                          0.595681
# Total crime against children                      1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(new_df.corr(),annot=True)
plt.savefig('heatmap1.jpg')
plt.show()

# %% [markdown]
# I see that the above heatmap shows the correlation matrix data wherein there are positive as well as negative correlations between the target label and other feture columns. A zero correlation indicates that there is no relationship between the variables. Looking at the above representation I see that quality column is positively correlated with alcohol and it is negatively correlated with the volatile acidity. The quality column is least correlated with residual sugar showing a coefficient value of 0.014 that close to 0. Similarly we can bifurcate all the other positively and negatively correlated feature columns with respect to the target label.
#
# Also there are some highly positive and negative correlated feature columns that can pose the concern for multicollinearity. If the correlation coefficient, assuming it to be the variable 'r', is exactly +1 or -1, then it is called perfect multicollinearity. But even if this 'r' is close to -1 or +1 then one of the features should be removed from the model if at all possible.
#
# * Lit_rate is Negatively corelated with the Tootal Crimes,, 'tot_crimes_sc', 'total crime against women','Total crimes against STs', 'Total crime against children'

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\91897\anaconda3\lib\site-packages (0.2.1)

# %%
import plotly.io as pio
pio.renderers.default = 'svg'

import plotly.express as px
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Literacy rate vs Total crimes

# %%
#plotting scatter plot
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['Lit_rate'], y=df['Total Crimes'],hue=df['State/UT'])
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes')
plt.title('Literacy Rate VS Total Crimes')
plt.savefig("12.jpg")
plt.show()

# %% [markdown]
# In the above plot we can see Lit_rate VS Total Crimes for every state here.

# %% [markdown]
# From the above scatter plot its clear that Higher the Literacy rate lower the Total Crimes would be.

# %%
## Literacy Rate VS Tot Crimes SC
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['Lit_rate'], y=df['tot_crimes_sc'],hue=df['State/UT'])
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes Against SC')
plt.title('Literact Rate VS Total Crimes Against SC')
plt.savefig("13.jpg")
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['Lit_rate'], y=df['total crime against women'],hue=df['State/UT'])
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes Against Women')
plt.title('Literact Rate VS Total Crimes Against WOmen')
plt.savefig("14.jpg")
plt.show()

# %% [markdown]
# Total crime against women kept decreasing with the increament in Literacy rate for each state.

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['Lit_rate'], y=df['Total crimes against STs'],hue=df['State/UT'])
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes Against STs')
plt.title('Literact Rate VS Total Crimes Against STs')
plt.savefig("15.jpg")
plt.show()

# %% [markdown]
# Lit_rate is negatively correlated with Total crimes against STs.

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x=df['Lit_rate'], y=df['Total crime against children'],hue=df['State/UT'])
plt.xlabel('Literacy Rate')
plt.ylabel('Total Crimes Against children')
plt.title('Literact Rate VS Total Crimes Against Children')
plt.savefig("16.jpg")

plt.show()

# %% [markdown]
# # 2.2 Analysis of the type of crime vs each state vs Literacy rate.

# %% [markdown]
# # State Vs MURDER Vs Litercay Rate

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\91897\anaconda3\lib\site-packages (0.2.1)

# %%
# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Bar width can be adjusted based on your preference
bar_width = 0.35

# Position of bars on x-axis
bar_positions1 = range(len(df['State/UT']))
bar_positions2 = [pos + bar_width for pos in bar_positions1]

# Bar plot for MurderRate
ax.bar(bar_positions1, df['MURDER'], width=bar_width, label='Murder Rate')

# Bar plot for LiteracyRate
ax.bar(bar_positions2, df['Lit_rate'], width=bar_width, label='Literacy Rate')

# X-axis ticks and labels
ax.set_xticks([pos + bar_width / 2 for pos in bar_positions1])
ax.set_xticklabels(df['State/UT'])

# Labels and title
ax.set_xlabel('State?UT')
ax.set_ylabel('Rates')
ax.set_title('Murder Rate and Literacy Rate by State')

# Legend
ax.legend()

# Show the plot
plt.show()

# %%
# 2.3 Analysis of Year-on-year total crime rate

# %% [markdown]
# * Crime rate= e following formula is used to calculate a crime rate
# * CR=TC/P∗100,000
# * Where CR is the rate of crimes per 100,000 people
# * TC is the total number of crimes committed in an area
# * P is the total population of the area

# %%
#selecting d/f states/UT for analysis
df_states=df[['State/UT','Year','Crime Rate']]

# %%
# Making data set for different state
#Selecting A& N Island only
select_andman = df_states.loc[df['State/UT'] == 'A& N ISLANDS']
select_andhra = df_states.loc[df['State/UT'] == 'ANDHRA PRADESH']
select_arunachal = df_states.loc[df['State/UT'] == 'ARUNACHAL PRADESH']
select_assam4 = df_states.loc[df['State/UT'] == 'ASSAM'] 
select_bihar = df_states.loc[df['State/UT'] == 'BIHAR'] 
select_chandigarh = df_states.loc[df['State/UT'] == 'CHANDIGARH']
select_chhatisgarh = df_states.loc[df['State/UT'] == 'CHHATTISGARH']
select_haveli = df_states.loc[df['State/UT'] == 'D & N HAVELI']
select_daman = df_states.loc[df['State/UT'] == 'DAMAN & DIU']
select_delhi = df_states.loc[df['State/UT'] == 'DELHI']  
select_goa = df_states.loc[df['State/UT'] == 'GOA']
select_gujarat = df_states.loc[df['State/UT'] == 'GUJARAT']
select_haryana = df_states.loc[df['State/UT'] == 'HARYANA']
select_himachal = df_states.loc[df['State/UT'] == 'HIMACHAL PRADESH']
select_jk = df_states.loc[df['State/UT'] == 'JAMMU & KASHMIR']
select_jharkhand = df_states.loc[df['State/UT'] == 'JHARKHAND']
select_karnataka = df_states.loc[df['State/UT'] == 'KARNATAKA'] 
select_kerala= df_states.loc[df['State/UT'] == 'KERALA'] 
select_lakshdweep= df_states.loc[df['State/UT'] == 'LAKSHADWEEP']
select_mp= df_states.loc[df['State/UT'] == 'MADHYA PRADESH']
select_maharashtra = df_states.loc[df['State/UT'] == 'MAHARASHTRA']  
select_manipur= df_states.loc[df['State/UT'] == 'MANIPUR'] 
select_meghalaya = df_states.loc[df['State/UT'] == 'MEGHALAYA']
select_mizoram = df_states.loc[df['State/UT'] == 'MIZORAM'] 
select_nagaland= df_states.loc[df['State/UT'] == 'NAGALAND']
select_odisha= df_states.loc[df['State/UT'] == 'ODISHA']
select_puducherry = df_states.loc[df['State/UT'] == 'PUDUCHERRY']
select_punjab = df_states.loc[df['State/UT'] == 'PUNJAB']
select_rajasthan = df_states.loc[df['State/UT'] == 'RAJASTHAN']
select_sikkim = df_states.loc[df['State/UT'] == 'SIKKIM']
select_tamilnadu = df_states.loc[df['State/UT'] == 'TAMIL NADU']
select_tripura= df_states.loc[df['State/UT'] == 'TRIPURA']
select_up = df_states.loc[df['State/UT'] == 'UTTAR PRADESH']
select_uk= df_states.loc[df['State/UT'] == 'UTTARAKHAND']
select_wb= df_states.loc[df['State/UT'] == 'WEST BENGAL']

# %%
# Crime Rate analysis of A & Islands year wise

# %%
fig = px.line(select_andman, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="2f5d1fc4-2119-4a82-ad4a-3ff666994530" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f5d1fc4-2119-4a82-ad4a-3ff666994530")) {                    Plotly.newPlot(                        "2f5d1fc4-2119-4a82-ad4a-3ff666994530",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[184.7525776,169.543988,178.3523456,205.7149143,186.2787407,183.3747464,217.4106313],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[184.7525776,169.543988,178.3523456,205.7149143,186.2787407,183.3747464,217.4106313],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true ...

# %% [markdown]
# As per above line plot crime rate was lowest in 2002 and highest after 2006.

# %% [markdown]
# # Crime Rate Analysis of Andhra Pradesh year wise

# %%
fig = px.line(select_andhra, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="9d671cfe-dc28-45d1-8621-231e156ec1c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d671cfe-dc28-45d1-8621-231e156ec1c3")) {                    Plotly.newPlot(                        "9d671cfe-dc28-45d1-8621-231e156ec1c3",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[170.6980554,186.3895353,201.488277,201.5880065,197.3436534,216.0500131,215.1468483],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[170.6980554,186.3895353,201.488277,201.5880065,197.3436534,216.0500131,215.1468483],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true ...

# %% [markdown]
# # Crime Rate Analysis of Arunachal Pradesh year wise

# %%
fig = px.line(select_arunachal, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="b804c157-45a3-44bd-b2cd-d8af93098991" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b804c157-45a3-44bd-b2cd-d8af93098991")) {                    Plotly.newPlot(                        "b804c157-45a3-44bd-b2cd-d8af93098991",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[213.3031199,198.3581147,179.3649385,191.9212714,191.5979636,186.4775337,181.6492897],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[213.3031199,198.3581147,179.3649385,191.9212714,191.5979636,186.4775337,181.6492897],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...

# %% [markdown]
# As per above Line plot Arunachal Pradesh has Lowest crime rate in between 2002 and 2004 and highest in 2001 which is a good thing that means Crime is decrasing in this state.

# %% [markdown]
# # Crime Rate Analysis of Assam year wise

# %%
fig = px.line(select_assam4, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="3deede79-1295-4735-9828-abff03b01b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3deede79-1295-4735-9828-abff03b01b10")) {                    Plotly.newPlot(                        "3deede79-1295-4735-9828-abff03b01b10",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[138.3465373,134.2071432,138.8135369,145.4987168,147.8935468,151.3412184,154.4458013],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[138.3465373,134.2071432,138.8135369,145.4987168,147.8935468,151.3412184,154.4458013],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...

# %% [markdown]
# # Crime Rate Analysis of Bihar year wise

# %%
fig = px.line(select_bihar, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="575e7cc8-89f2-4818-8022-5a9097a64487" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("575e7cc8-89f2-4818-8022-5a9097a64487")) {                    Plotly.newPlot(                        "575e7cc8-89f2-4818-8022-5a9097a64487",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[106.5464923,110.7558564,106.2199327,121.6095787,107.6435513,108.2505362,115.0198084],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[106.5464923,110.7558564,106.2199327,121.6095787,107.6435513,108.2505362,115.0198084],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...

# %% [markdown]
# It is clear from above plot that Bihar has Increasing trend for Crime rate that means Crime rate is keep on increasing from 2001

# %% [markdown]
# # Crime Rate Analysis of Chandighar year wise

# %%
fig = px.line(select_chandigarh, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="7805487f-8603-4484-8993-3c6ead302bc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7805487f-8603-4484-8993-3c6ead302bc3")) {                    Plotly.newPlot(                        "7805487f-8603-4484-8993-3c6ead302bc3",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[377.1783242,415.9358283,301.822985,305.8573428,326.4663895,320.6074927,367.7483765],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[377.1783242,415.9358283,301.822985,305.8573428,326.4663895,320.6074927,367.7483765],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true ...

# %% [markdown]
# # Crime Rate Analysis of Chhatisgarh year wise

# %%
fig = px.line(select_chhatisgarh, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="a996315b-962b-45fe-84d1-6135be106e8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a996315b-962b-45fe-84d1-6135be106e8f")) {                    Plotly.newPlot(                        "a996315b-962b-45fe-84d1-6135be106e8f",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[184.6038383,178.4093055,177.0374152,189.0810827,192.7274783,195.4430453,194.2536018],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[184.6038383,178.4093055,177.0374152,189.0810827,192.7274783,195.4430453,194.2536018],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...

# %% [markdown]
# # Crime Rate Analysis of D & N Haveli year wise

# %%
fig = px.line(select_haveli, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="8a13fee8-13d4-4be1-b2d0-4c0ff0032a81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a13fee8-13d4-4be1-b2d0-4c0ff0032a81")) {                    Plotly.newPlot(                        "8a13fee8-13d4-4be1-b2d0-4c0ff0032a81",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[158.7373577,151.4684629,140.3776907,162.5518656,165.0604334,158.3171073,148.0176089],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[158.7373577,151.4684629,140.3776907,162.5518656,165.0604334,158.3171073,148.0176089],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...

# %% [markdown]
# # Crime Rate Analysis of Daman & Diu year wise

# %%
fig = px.line(select_daman, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="8894a33c-14b3-4d79-8deb-1bf95a3a66d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8894a33c-14b3-4d79-8deb-1bf95a3a66d3")) {                    Plotly.newPlot(                        "8894a33c-14b3-4d79-8deb-1bf95a3a66d3",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[221.2333443,211.305127,196.021574,227.2020265,230.9296782,221.7080182,207.4830596],"x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[221.2333443,211.305127,196.021574,227.2020265,230.9296782,221.7080182,207.4830596],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true," ...

# %% [markdown]
# Daman & DIu Crime rate was highest in 2005 since then its decreasing

# %% [markdown]
# # Crime Rate Analysis of Delhi year wise

# %%
fig = px.line(select_delhi, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="b457b55d-83c1-4cf5-a359-6b5a43d7f852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b457b55d-83c1-4cf5-a359-6b5a43d7f852")) {                    Plotly.newPlot(                        "b457b55d-83c1-4cf5-a359-6b5a43d7f852",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[392.6498864,348.1519506,329.610509,365.9004999,375.4305247,380.903051],"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[392.6498864,348.1519506,329.610509,365.9004999,375.4305247,380.903051],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"ma ...

# %% [markdown]
# Delhi Crime rate was at peak in 2001 and it has increased back since 2003 till 2008

# %% [markdown]
# # Crime Rate Analysis of GOA year wise

# %%
fig = px.line(select_goa, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="d7b96d11-995e-40d4-b592-34f0fe433a47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7b96d11-995e-40d4-b592-34f0fe433a47")) {                    Plotly.newPlot(                        "d7b96d11-995e-40d4-b592-34f0fe433a47",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[173.707471,179.6168713,163.8775592,154.100508,153.405212,158.2925093],"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[173.707471,179.6168713,163.8775592,154.100508,153.405212,158.2925093],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"mark ...

# %% [markdown]
# # Crime Rate Analysis of GUJARAT year wise

# %%
fig = px.line(select_gujarat, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="ed6a23d4-7bfb-477e-8f24-22191e0c61bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed6a23d4-7bfb-477e-8f24-22191e0c61bb")) {                    Plotly.newPlot(                        "ed6a23d4-7bfb-477e-8f24-22191e0c61bb",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[204.0989231,206.8022479,197.49736,197.2976457,208.4087665,218.3666986],"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[204.0989231,206.8022479,197.49736,197.2976457,208.4087665,218.3666986],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"ma ...

# %% [markdown]
# # Crime Rate Analysis of HARYANA year wise

# %%
fig = px.line(select_haryana, x='Year', y='Crime Rate', text='Crime Rate', markers=True)
fig.show()
# Out:
# <div>                            <div id="9ccbc3b1-c091-4c44-9b01-5759ed4c9c7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ccbc3b1-c091-4c44-9b01-5759ed4c9c7e")) {                    Plotly.newPlot(                        "9ccbc3b1-c091-4c44-9b01-5759ed4c9c7e",                        [{"hovertemplate":"Year=%{x}<br>Crime Rate=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"text+markers+lines","name":"","orientation":"v","showlegend":false,"text":[183.3047964,186.5351468,176.2090815,175.2631267,187.8763146,218.4899541],"x":[2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[183.3047964,186.5351468,176.2090815,175.2631267,187.8763146,218.4899541],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[ ...

# %% [markdown]
# We have seen the crimes rate increasing and decreasing over the year for several years for different states.
# Now lets move further to next point of Analysis of Are vs Overall crime.

# %% [markdown]
# # 2.4 Analysis of area vs overall crime

# %%
df_area=df.groupby('Area (km2)').min()

# %%
dfarea=pd.pivot_table(df, values ='Area (km2)', index =['State/UT','Year','Total Crimes'],
                          aggfunc = max)
dfarea
# Out:
#                                 Area (km2)
# State/UT     Year Total Crimes
# A& N ISLANDS 2001 1386                8249
#              2002 1269                8249
#              2003 1352                8249
#              2004 1612                8249
#              2005 1462                8249
# ...                                    ...
# WEST BENGAL  2002 131963             88752
#              2003 136865             88752
#              2004 155840             88752
#              2005 147829             88752
#              2006 151722             88752
#
# [219 rows x 1 columns]

# %%
df_area=df[['State/UT','Year','Total Crimes','Area (km2)']]
df_area
# Out:
#               State/UT  Year  Total Crimes  Area (km2)
# 0         A& N ISLANDS  2001          1386        8249
# 1       ANDHRA PRADESH  2001        278982      275045
# 2    ARUNACHAL PRADESH  2001          5243       83743
# 3                ASSAM  2001         81418       78438
# 4                BIHAR  2001        189612       94163
# ..                 ...   ...           ...         ...
# 214              BIHAR  2007        234720       94163
# 215         CHANDIGARH  2007          9100         114
# 216       CHHATTISGARH  2007         98297      135191
# 217       D & N HAVELI  2007           953         491
# 218        DAMAN & DIU  2007           953         112
#
# [219 rows x 4 columns]

# %%
fig = px.scatter(df_area, x="Area (km2)", y="Total Crimes", size="Area (km2)",color='State/UT',
                  size_max=50)
fig.show()
# Out:
# <div>                            <div id="672f1bf1-5063-49f8-a55b-505957c039ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("672f1bf1-5063-49f8-a55b-505957c039ff")) {                    Plotly.newPlot(                        "672f1bf1-5063-49f8-a55b-505957c039ff",                        [{"hovertemplate":"State/UT=A& N ISLANDS<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"A& N ISLANDS","marker":{"color":"#636efa","size":[8249,8249,8249,8249,8249,8249,8249],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"A& N ISLANDS","orientation":"v","showlegend":true,"x":[8249,8249,8249,8249,8249,8249,8249],"xaxis":"x","y":[1386,1269,1352,1612,1462,1464,1741],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=ANDHRA PRADESH<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"ANDHRA PRADESH","marker":{"color":"#EF553B","size":[275045,275045,275045,275045,275045,275045,275045],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"ANDHRA PRADESH","orientation":"v","showlegend":true,"x":[275045,275045,275045,275045,275045,275045,275045],"xaxis":"x","y":[278982,308746,339741,343632,340571,374407,377732],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=ARUNACHAL PRADESH<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"ARUNACHAL PRADESH","marker":{"color":"#00cc96","size":[83743,83743,83743,83743,83743,83743,83743],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"ARUNACHAL PRADESH","orientation":"v","showlegend":true,"x":[83743,83743,83743,83743,83743,83743,83743],"xaxis":"x","y":[5243,4946,4591,5007,5232,5151,5201],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=ASSAM<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"ASSAM","marker":{"color":"#ab63fa","size":[78438,78438,78438,78438,78438,78438,78438],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"ASSAM","orientation":"v","showlegend":true,"x":[78438,78438,78438,78438,78438,78438,78438],"xaxis":"x","y":[81418,80812,84638,90293,93370,98235,101726],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=BIHAR<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"BIHAR","marker":{"color":"#FFA15A","size":[94163,94163,94163,94163,94163,94163,94163],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"BIHAR","orientation":"v","showlegend":true,"x":[94163,94163,94163,94163,94163,94163,94163],"xaxis":"x","y":[189612,201626,198062,232036,210352,216933,234720],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=CHANDIGARH<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"CHANDIGARH","marker":{"color":"#19d3f3","size":[114,114,114,114,114,114,114],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"CHANDIGARH","orientation":"v","showlegend":true,"x":[114,114,114,114,114,114,114],"xaxis":"x","y":[8397,9331,6900,7310,7726,7570,9100],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=CHHATTISGARH<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"CHHATTISGARH","marker":{"color":"#FF6692","size":[135191,135191,135191,135191,135191,135191,135191],"sizemode":"area","sizeref":136.8956,"symbol":"circle"},"mode":"markers","name":"CHHATTISGARH","orientation":"v","showlegend":true,"x":[135191,135191,135191,135191,135191,135191,135191],"xaxis":"x","y":[82898,81372,82143,90051,94102,96850,98297],"yaxis":"y","type":"scatter"},{"hovertemplate":"State/UT=D & N HAVELI<br>Area (km2)=%{marker.size}<br>Total Crimes=%{y}<extra></extra>","legendgroup":"D & N HAVELI", ...

# %% [markdown]
# Above Scatter plot is showing us the Area VS Total Crimes.Since the Area will remain the same so the size of the circle are equal for every state Area Correspondingly.Diffrent Color showing the different State/UT and Tota Crimes on y-axis.
#
# Observations
#
# * From above representaion its is clear that smaller the Area of the state lesser Total Crimes would be. For example Lakshdweep Area is 72 KM2 and Total crimes are only 127 which is showing afetr hovering over the Lakshdweep circle
#
# * Similarly with Puducherry state Area-479km2 and Total Crimes 9252.
#
# * The Area of Rajasthan state is 342239(Largest) Km2 and Total Crime are like 370.502K
#
# * While the Uttar Pradesh has 240928 km2 area and Total Crimes are 444.403K Total Crimes which is the Highest.

# %% [markdown]
# # 2.5 Analysis of Population vs overall Crime

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax2 = ax.twinx()
ax.set_title('Population VS Total Crimes')
ax.set_xlabel('Year')



ax.plot(df['Year'],df['population(total)'], color='green', marker='x')
ax2.plot(df['Year'],df['Total Crimes'], color='red', marker='o')



ax.set_ylabel('population(total)')
ax2.set_ylabel('Total Crimes')
ax.legend(['Population(total)'])
ax2.legend(['Total Crimes'], loc='upper center')
ax.set_xticks(df['Year'])
ax.set_xticklabels(df['Year'], rotation=90)
ax.yaxis.grid(color='lightgray', linestyle='dashed')

plt.savefig('18.jpg')

plt.tight_layout()
plt.show()

# %% [markdown]
# In above line plot we can Clearly see that More the population chances of Crimes would be higher. x axis showing population increament year wise correspondigly increament in Total Crimes. y-axis on lefy side showing Population data and Y axis on right side shwoing Total crimes

# %% [markdown]
# * Population is one of the important factors influencing incidence of crime. A number of socio-economic factors, besides population, could influence the crime situation at a particular place.

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax2 = ax.twinx()
ax.set_title('Population VS CRIME RATE')
ax.set_xlabel('Year')


plt.savefig('19.jpg')

ax.plot(df['Year'],df['population(total)'], color='green', marker='x')
ax2.plot(df['Year'],df['Crime Rate'], color='red', marker='o')



ax.set_ylabel('population(total)')
ax2.set_ylabel('Crime Rate')
ax.legend(['Population(total)'])
ax2.legend(['Crime Rate'], loc='upper center')
ax.set_xticks(df['Year'])
ax.set_xticklabels(df['Year'], rotation=90)
ax.yaxis.grid(color='lightgray', linestyle='dashed')
plt.savefig('20.jpg')


plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.6 Each state crime report.

# %% [markdown]
# * There is no fixed format to write a report, we can write a report inside the notebook itself based on what we have analyzed in the above points.

# %%
tc= df.groupby("State/UT")["TOTAL IPC CRIMES"].sum().sort_values(ascending = False)
print("Crime by Each state:\n",tc)
# Out:
# Crime by Each state:
#  State/UT
# MADHYA PRADESH       1145368
# ANDHRA PRADESH       1095525
# MAHARASHTRA          1056118
# TAMIL NADU            956867
# RAJASTHAN             889780
# UTTAR PRADESH         798529
# BIHAR                 690730
# KARNATAKA             684932
# GUJARAT               653658
# KERALA                620501
# WEST BENGAL           385507
# DELHI                 318576
# ODISHA                294886
# CHHATTISGARH          291441
# ASSAM                 283054
# HARYANA               249792
# JHARKHAND             192067
# PUNJAB                170158
# JAMMU & KASHMIR       122798
# HIMACHAL PRADESH       73517
# UTTARAKHAND            49051
# PUDUCHERRY             26904
# CHANDIGARH             22800
# TRIPURA                19767
# MANIPUR                15942
# ARUNACHAL PRADESH      15771
# MIZORAM                14266
# GOA                    13475
# MEGHALAYA              10587
# NAGALAND                6460
# A& N ISLANDS            4823
# SIKKIM                  3258
# D & N HAVELI            2740
# DAMAN & DIU             2740
# LAKSHADWEEP              312
# Name: TOTAL IPC CRIMES, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.barplot(x = tc.index[:12], y = tc[:12]).set(title = "Crime by Each state")
plt.savefig('crimebyeachstate.jpg')
plt.show()

# %% [markdown]
# # From Above Bar plot we can see Top 12 states which have higher IPC Crimes - TOP 3 States are Madhya Pradesh, Maharashtra and Tamil Nadu

# %%
tcr= df.groupby("State/UT")["Crime Rate"].sum().sort_values(ascending = False)
print("Crime  Rate  of Each state:\n",tcr)
# Out:
# Crime  Rate  of Each state:
#  State/UT
# MAHARASHTRA          18547.590255
# MADHYA PRADESH        4519.479679
# PUDUCHERRY            2593.912958
# CHANDIGARH            2415.616739
# DELHI                 2192.646422
# KERALA                1924.550510
# MIZORAM               1537.050776
# DAMAN & DIU           1515.882828
# RAJASTHAN             1500.893171
# TAMIL NADU            1478.128837
# ANDHRA PRADESH        1388.704389
# ARUNACHAL PRADESH     1342.672231
# A& N ISLANDS          1325.427944
# CHHATTISGARH          1311.555767
# KARNATAKA             1248.260034
# GUJARAT               1232.471642
# HIMACHAL PRADESH      1173.466746
# JAMMU & KASHMIR       1146.570650
# HARYANA               1127.678420
# D & N HAVELI          1084.530526
# ASSAM                 1010.546501
# GOA                    983.000131
# BIHAR                  776.045756
# ODISHA                 775.204053
# MANIPUR                704.575040
# JHARKHAND              676.468386
# PUNJAB                 676.173654
# TRIPURA                595.655023
# SIKKIM                 583.009576
# UTTARAKHAND            552.589165
# LAKSHADWEEP            505.748233
# WEST BENGAL            465.168949
# UTTAR PRADESH          460.224949
# MEGHALAYA              428.638152
# NAGALAND               325.410126
# Name: Crime Rate, dtype: float64

# %%
plt.figure(figsize=(16,6))
sns.barplot(x = tcr.index[:12], y = tcr[:12]).set(title = "Crime  Rate for Each state")
plt.savefig('crimeratestate.jpg')
plt.show()

# %% [markdown]
# * Maharashtra State is the one which i having the highest crime rate and Nagaland is the state which has lowest crime rate

# %% [markdown]
# * A& N ISLANDS- In 2001 Andaman had 184.75 Crime Rate which got declined in 2012 as population got increased and it was highest in 2009 (250.04 Crime Rate).Its Area is 8249KM2
# * ANDHRA PRADESH- Total IPC crimes were 2018981in 2012 in which that population were highest too
# * ARUNACHAL PRADESH- with count of Total IPC Crimes 27652 – on population of 1407014 which make s crime rate of 171.
# * ASSAM- 597764 with total IPC crimes Assam state comes at 14th position
# * BIHAR- 1346293 Total IPC crimes comes at 10th position
# * CHANDIGARH- 40807 total ipc crimes is less populated and crimes are less heer as comare to ither state /UTs
# * CHHATTISGARH-with total ipc crimes 561027 Chhatisgarh comes at 15th position
# * D & N HAVELI- Being an UT with an area of 491 km square has only 4651 total IPC crimes in the san of 11 years.
# * DAMAN & DIU- Its also an UT which has less area and crimes are 4651 , with an area of 12 km square it means leeser the area , less populated and less crimes
# * DELHI – Being the Capital of India , Delhi has 633174 crime count in the span of 2001 to 2012. Delhi is wast in area wise 16579 km2 which is large in size.
# * GOA- with an area of 3702 km2 , Goa is the smalles state of India also it has 32051 count of crime , which has happened in the span of 11 years.(2001 to 2012)
# * GUJARAT – is the hub for textile business , and it has crimes 1385775 and it comes at 8th position.
# * HARYANA – 595303 total ipc crimes happened in the duration of 11 year it is 44212 km2 spread and it has 245 crime rate per capita.
# * HIMACHAL PRADESH – 154948 crimes were happened in the duration of 11 years (2001-2012)
# * JAMMU & KASHMIR – 259155 crimes were reported in the duration of 11 years (2001-2012)
# * JHARKHAND – 422351 crmes were reorted in the span of 11 years (2001 to 2012)
# * KARNATAKA -1481063 crimes were happened in the duration of 11 years with the population count of 61290592 that means it has crime rate of 214 (avg)
# * KERALA – Being the no.1 state in literacy – Kearala still has 1437459 total crime count in the span of 11 yaers
# * LAKSHADWEEP – 743 the lowest crime count for any UT also its in small in area as well only 32 km square.
# * MADHYA PRADESH – is in the Top 3 states with higher crimes 2413770, also its large in area and Population wise as well.
# * MAHARASHTRA – 2nd State with highest crime with largest population and area covered
# * MANIPUR- Small state and less populated as well
# * MEGHALAYA – Small state and less populated
# * MIZORAM – 1110132 count of Population and total Crimes are 35072.
# * NAGALAND – 13133 crimes were happened in the duration of 2001 to 2012
# * ODISHA – 647946 crimes were happened in the duration of 11 years.
# * PUDUCHERRY-54116 total crimes were happened in the span of 1 years
# * PUNJAB - 384131 crimes were happened in the duration of 11 years.
# * RAJASTHAN- In terms of area, the largest state in India is Rajasthan.It covers an area of over 342,000 square kilometers
# * SIKKIM- 7000 crimes were reported in the span of 11 years.
# * TAMIL NADU – 3rd State with highest crimes in india 2060176 crime count.
# * TRIPURA – 52734 total Ipc counts in the duration of 11 years.
# * UTTAR PRADESH- Most Populated state and at 5th position in total crimes against
# * UTTARAKHAND – 103204 total counts IPC crimes in the durationoof 11 years.
# * WEST BENGAL- 1119304 crimes were recorded in the duration of 2001 to 2012.
